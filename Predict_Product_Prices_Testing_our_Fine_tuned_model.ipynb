# %% [markdown]
# <a href="https://colab.research.google.com/github/kmalhotra18/Product-Pricer/blob/main/Predict_Product_Prices_Testing_our_Fine_tuned_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Predict Product Prices
#
# ### And now, to evaluate our fine-tuned open source model

# %%
# pip installs

# !pip install -q datasets peft requests torch bitsandbytes transformers trl accelerate sentencepiece matplotlib
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 41.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 35.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 36.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 104.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 10.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 348.0/348.0 kB 21.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 33.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 15.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.

# %%
# imports

import os
import re
import math
from tqdm import tqdm
from google.colab import userdata
from huggingface_hub import login
import torch
import torch.nn.functional as F
import transformers
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, set_seed
from datasets import load_dataset, Dataset, DatasetDict
from datetime import datetime
from peft import PeftModel
import matplotlib.pyplot as plt

# %%
# Constants

BASE_MODEL = "meta-llama/Meta-Llama-3.1-8B"
PROJECT_NAME = "pricer"
HF_USER = "kmalhotra18" # your HF name here! Or use mine if you just want to reproduce my results.

# The run itself

RUN_NAME = "2025-05-25_16.34.34"
PROJECT_RUN_NAME = f"{PROJECT_NAME}-{RUN_NAME}"
# REVISION = "e8d637df551603dc86cd7a1598a8f44af4d7ae36" # or
REVISION = None
FINETUNED_MODEL = f"{HF_USER}/{PROJECT_RUN_NAME}"


# Data

DATASET_NAME = f"{HF_USER}/pricer-data"

# Hyperparameters for QLoRA

QUANT_4_BIT = True

# %matplotlib inline

# Used for writing to output in color

GREEN = "\033[92m"
YELLOW = "\033[93m"
RED = "\033[91m"
RESET = "\033[0m"
COLOR_MAP = {"red":RED, "orange": YELLOW, "green": GREEN}

# %%
# Log in to HuggingFace

hf_token = userdata.get('HF_TOKEN')
login(hf_token, add_to_git_credential=True)

# %%
dataset = load_dataset(DATASET_NAME)
train = dataset['train']
test = dataset['test']
# Out:
# README.md:   0%|          | 0.00/416 [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/187M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/922k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/400000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2000 [00:00<?, ? examples/s]

# %%
test[0]
# Out:
# {'text': "How much does this cost to the nearest dollar?\n\nOEM AC Compressor w/A/C Repair Kit For Ford F150 F-150 V8 & Lincoln Mark LT 2007 2008 - BuyAutoParts NEW\nAs one of the world's largest automotive parts suppliers, our parts are trusted every day by mechanics and vehicle owners worldwide. This A/C Compressor and Components Kit is manufactured and tested to the strictest OE standards for unparalleled performance. Built for trouble-free ownership and 100% visually inspected and quality tested, this A/C Compressor and Components Kit is backed by our 100% satisfaction guarantee. Guaranteed Exact Fit for easy installation 100% BRAND NEW, premium ISO/TS 16949 quality - tested to meet or exceed OEM specifications Engineered for superior durability, backed by industry-leading unlimited-mileage warranty Included in this K\n\nPrice is $",
#  'price': 374.41}

# %% [markdown]
# ## Now load the Tokenizer and Model

# %%
# pick the right quantization

if QUANT_4_BIT:
  quant_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=torch.bfloat16,
    bnb_4bit_quant_type="nf4"
  )
else:
  quant_config = BitsAndBytesConfig(
    load_in_8bit=True,
    bnb_8bit_compute_dtype=torch.bfloat16
  )

# %%
# Load the Tokenizer and the Model

tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

base_model = AutoModelForCausalLM.from_pretrained(
    BASE_MODEL,
    quantization_config=quant_config,
    device_map="auto",
)
base_model.generation_config.pad_token_id = tokenizer.pad_token_id

# Load the fine-tuned model with PEFT - Parameter Efficient Fine Tuning (LoRA)

if REVISION:
  fine_tuned_model = PeftModel.from_pretrained(base_model, FINETUNED_MODEL, revision=REVISION)
else:
  fine_tuned_model = PeftModel.from_pretrained(base_model, FINETUNED_MODEL)


print(f"Memory footprint: {fine_tuned_model.get_memory_footprint() / 1e6:.1f} MB")
# Out:
# tokenizer_config.json:   0%|          | 0.00/50.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/826 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/185 [00:00<?, ?B/s]
# adapter_config.json:   0%|          | 0.00/810 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/27.3M [00:00<?, ?B/s]
# Memory footprint: 5618.8 MB

# %%
fine_tuned_model
# Out:
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): LlamaForCausalLM(
#       (model): LlamaModel(
#         (embed_tokens): Embedding(128256, 4096)
#         (layers): ModuleList(
#           (0-31): 32 x LlamaDecoderLayer(
#             (self_attn): LlamaAttention(
#               (q_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (k_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (v_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (o_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#             )
#             (mlp): LlamaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (act_fn): SiLU()
#             )
#             (input_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#             (post_attention_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#           )
#         )
#         (norm): LlamaRMSNorm((4096,), eps=1e-05)
#         (rotary_emb): LlamaRotaryEmbedding()
#       )
#       (lm_head): Linear(in_features=4096, out_features=128256, bias=False)
#     )
#   )
# )

# %% [markdown]
# # THE MOMENT OF TRUTH!
#
# ## Use the model in inference mode
#
# Remember, GPT-4o had an average error of \$76.
# Llama 3.1 base model had an average error of \$396.
# This human had an error of \$127.
#
# ## Caveat
#
# Keep in mind that prices of goods vary considerably; the model can't predict things like sale prices that it doesn't have any information about.

# %%
def extract_price(s):
    if "Price is $" in s:
      contents = s.split("Price is $")[1]
      contents = contents.replace(',','')
      match = re.search(r"[-+]?\d*\.\d+|\d+", contents)
      return float(match.group()) if match else 0
    return 0

# %%
extract_price("Price is $a fabulous 899.99 or so")
# Out:
# 899.99

# %%
# Original prediction function takes the most likely next token

def model_predict(prompt):
    set_seed(42)
    inputs = tokenizer.encode(prompt, return_tensors="pt").to("cuda")
    attention_mask = torch.ones(inputs.shape, device="cuda")
    outputs = fine_tuned_model.generate(inputs, attention_mask=attention_mask, max_new_tokens=3, num_return_sequences=1)
    response = tokenizer.decode(outputs[0])
    return extract_price(response)

# %%
# An improved prediction function takes a weighted average of the top 3 choices
# This code would be more complex if we couldn't take advantage of the fact
# That Llama generates 1 token for any 3 digit number

top_K = 3

def improved_model_predict(prompt, device="cuda"):
    set_seed(42)
    inputs = tokenizer.encode(prompt, return_tensors="pt").to(device)
    attention_mask = torch.ones(inputs.shape, device=device)

    with torch.no_grad():
        outputs = fine_tuned_model(inputs, attention_mask=attention_mask)
        next_token_logits = outputs.logits[:, -1, :].to('cpu')

    next_token_probs = F.softmax(next_token_logits, dim=-1)         # use softmax function to turn into probabilities
    top_prob, top_token_id = next_token_probs.topk(top_K)
    prices, weights = [], []
    for i in range(top_K):
      predicted_token = tokenizer.decode(top_token_id[0][i])
      probability = top_prob[0][i]
      try:
        result = float(predicted_token)
      except ValueError as e:
        result = 0.0
      if result > 0:
        prices.append(result)
        weights.append(probability)
    if not prices:
      return 0.0, 0.0
    total = sum(weights)
    weighted_prices = [price * weight / total for price, weight in zip(prices, weights)]
    return sum(weighted_prices).item()

# %%
class Tester:

    def __init__(self, predictor, data, title=None, size=250):
        self.predictor = predictor
        self.data = data
        self.title = title or predictor.__name__.replace("_", " ").title()
        self.size = size
        self.guesses = []
        self.truths = []
        self.errors = []
        self.sles = []
        self.colors = []

    def color_for(self, error, truth):
        if error<40 or error/truth < 0.2:
            return "green"
        elif error<80 or error/truth < 0.4:
            return "orange"
        else:
            return "red"

    def run_datapoint(self, i):
        datapoint = self.data[i]
        guess = self.predictor(datapoint["text"])
        truth = datapoint["price"]
        error = abs(guess - truth)
        log_error = math.log(truth+1) - math.log(guess+1)
        sle = log_error ** 2
        color = self.color_for(error, truth)
        title = datapoint["text"].split("\n\n")[1][:20] + "..."
        self.guesses.append(guess)
        self.truths.append(truth)
        self.errors.append(error)
        self.sles.append(sle)
        self.colors.append(color)
        print(f"{COLOR_MAP[color]}{i+1}: Guess: ${guess:,.2f} Truth: ${truth:,.2f} Error: ${error:,.2f} SLE: {sle:,.2f} Item: {title}{RESET}")

    def chart(self, title):
        max_error = max(self.errors)
        plt.figure(figsize=(12, 8))
        max_val = max(max(self.truths), max(self.guesses))
        plt.plot([0, max_val], [0, max_val], color='deepskyblue', lw=2, alpha=0.6)
        plt.scatter(self.truths, self.guesses, s=3, c=self.colors)
        plt.xlabel('Ground Truth')
        plt.ylabel('Model Estimate')
        plt.xlim(0, max_val)
        plt.ylim(0, max_val)
        plt.title(title)
        plt.show()

    def report(self):
        average_error = sum(self.errors) / self.size
        rmsle = math.sqrt(sum(self.sles) / self.size)
        hits = sum(1 for color in self.colors if color=="green")
        title = f"{self.title} Error=${average_error:,.2f} RMSLE={rmsle:,.2f} Hits={hits/self.size*100:.1f}%"
        self.chart(title)

    def run(self):
        self.error = 0
        for i in range(self.size):
            self.run_datapoint(i)
        self.report()

    @classmethod
    def test(cls, function, data):
        cls(function, data).run()

# %%
Tester.test(improved_model_predict, test)
# Out:
# 1: Guess: $189.88 Truth: $374.41 Error: $184.54 SLE: 0.46 Item: OEM AC Compressor w/...
# 2: Guess: $46.25 Truth: $225.11 Error: $178.86 SLE: 2.45 Item: Motorcraft YB3125 Fa...
# 3: Guess: $25.03 Truth: $61.68 Error: $36.65 SLE: 0.77 Item: Dorman Front Washer ...
# 4: Guess: $395.50 Truth: $599.99 Error: $204.49 SLE: 0.17 Item: HP Premium HD Plus T...
# 5: Guess: $28.48 Truth: $16.99 Error: $11.49 SLE: 0.24 Item: Super Switch Pickup ...
# 6: Guess: $11.04 Truth: $31.99 Error: $20.95 SLE: 1.02 Item: Horror Bookmarks, Re...
# 7: Guess: $58.88 Truth: $101.79 Error: $42.92 SLE: 0.29 Item: SK6241 - Stinger 4 G...
# 8: Guess: $273.00 Truth: $289.00 Error: $16.00 SLE: 0.00 Item: Godox ML60Bi LED Lig...
# 9: Guess: $702.50 Truth: $635.86 Error: $66.64 SLE: 0.01 Item: Randall G3 Plus Comb...
# 10: Guess: $38.94 Truth: $65.99 Error: $27.05 SLE: 0.27 Item: HOLDWILL 6 Pack LED ...
# 11: Guess: $227.38 Truth: $254.21 Error: $26.84 SLE: 0.01 Item: Viking Horns 3 Gallo...
# 12: Guess: $59.00 Truth: $412.99 Error: $353.99 SLE: 3.73 Item: CURT 70110 Custom To...
# 13: Guess: $24.59 Truth: $205.50 Error: $180.91 SLE: 4.36 Item: Solar HAMMERED BRONZ...
# 14: Guess: $250.75 Truth: $248.23 Error: $2.52 SLE: 0.00 Item: COSTWAY Electric Tum...
# 15: Guess: $303.00 Truth: $399.00 Error: $96.00 SLE: 0.08 Item: FREE SIGNAL TV Trans...
# 16: Guess: $256.50 Truth: $373.94 Error: $117.44 SLE: 0.14 Item: Bilstein 5100 Monotu...
# 17: Guess: $90.19 Truth: $92.89 Error: $2.70 SLE: 0.00 Item: Sangean K-200 Multi-...
# 18: Guess: $58.91 Truth: $51.99 Error: $6.92 SLE: 0.02 Item: Charles Leonard Magn...
# 19: Guess: $171.75 Truth: $179.00 Error: $7.25 SLE: 0.00 Item: Gigabyte AMD Radeon ...
# 20: Guess: $11.92 Truth: $19.42 Error: $7.50 SLE: 0.21 Item: 3dRose LLC 8 x 8 x 0...
# 21: Guess: $313.50 Truth: $539.95 Error: $226.45 SLE: 0.29 Item: ROKINON 85mm F1.4 Au...
# 22: Guess: $50.66 Truth: $147.67 Error: $97.01 SLE: 1.12 Item: Headlight Assembly C...
# 23: Guess: $28.31 Truth: $24.99 Error: $3.32 SLE: 0.01 Item: ASI NAUTICAL 2.5 Inc...
# 24: Guess: $79.50 Truth: $149.00 Error: $69.50 SLE: 0.39 Item: Behringer TUBE OVERD...
# 25: Guess: $11.92 Truth: $16.99 Error: $5.07 SLE: 0.11 Item: Fun Express Insect F...
# 26: Guess: $10.92 Truth: $7.99 Error: $2.93 SLE: 0.08 Item: WAFJAMF Roller Stamp...
# 27: Guess: $132.25 Truth: $199.99 Error: $67.74 SLE: 0.17 Item: Capulina Tiffany Flo...
# 28: Guess: $257.75 Truth: $251.45 Error: $6.30 SLE: 0.00 Item: Apple Watch Series 6...
# 29: Guess: $37.38 Truth: $231.62 Error: $194.25 SLE: 3.25 Item: ICON 01725 Tandem Ax...
# 30: Guess: $116.50 Truth: $135.00 Error: $18.50 SLE: 0.02 Item: SanDisk 128GB Ultra ...
# 31: Guess: $171.38 Truth: $356.62 Error: $185.25 SLE: 0.53 Item: Velvac - 715427
# 2020...
# 32: Guess: $109.62 Truth: $257.99 Error: $148.37 SLE: 0.72 Item: TCMT Passenger Backr...
# 33: Guess: $27.28 Truth: $27.99 Error: $0.71 SLE: 0.00 Item: Alnicov 63.5MM Brass...
# 34: Guess: $54.66 Truth: $171.20 Error: $116.54 SLE: 1.28 Item: Subaru Forester Outb...
# 35: Guess: $134.62 Truth: $225.00 Error: $90.38 SLE: 0.26 Item: Richmond Auto Uphols...
# 36: Guess: $117.00 Truth: $105.00 Error: $12.00 SLE: 0.01 Item: AP-39 Automotive Pai...
# 37: Guess: $162.62 Truth: $299.99 Error: $137.37 SLE: 0.37 Item: Road Top Wireless Ca...
# 38: Guess: $272.25 Truth: $535.09 Error: $262.84 SLE: 0.45 Item: Gibson Performance E...
# 39: Guess: $15.98 Truth: $12.33 Error: $3.65 SLE: 0.06 Item: Bella Tunno Happy Li...
# 40: Guess: $101.88 Truth: $84.99 Error: $16.89 SLE: 0.03 Item: CANMORE H300 Handhel...
# 41: Guess: $28.19 Truth: $15.99 Error: $12.20 SLE: 0.29 Item: DCPOWER AC Adapter C...
# 42: Guess: $23.47 Truth: $62.44 Error: $38.97 SLE: 0.91 Item: Sharp, Commercial De...
# 43: Guess: $49.84 Truth: $82.99 Error: $33.15 SLE: 0.25 Item: Melissa & Doug Lifel...
# 44: Guess: $276.50 Truth: $599.95 Error: $323.45 SLE: 0.60 Item: Sony SSCS8 2-Way Cen...
# 45: Guess: $254.88 Truth: $194.99 Error: $59.88 SLE: 0.07 Item: ASUS Chromebook CX1,...
# 46: Guess: $279.00 Truth: $344.95 Error: $65.95 SLE: 0.04 Item: FiiO X7 32GB Hi-Res ...
# 47: Guess: $39.12 Truth: $37.99 Error: $1.13 SLE: 0.00 Item: TORRO Leather Case C...
# 48: Guess: $228.00 Truth: $224.35 Error: $3.65 SLE: 0.00 Item: Universal Air Condit...
# 49: Guess: $282.50 Truth: $814.00 Error: $531.50 SLE: 1.12 Item: Street Series Stainl...
# 50: Guess: $337.50 Truth: $439.88 Error: $102.38 SLE: 0.07 Item: Lenovo IdeaPad 3 Lap...
# 51: Guess: $163.00 Truth: $341.43 Error: $178.43 SLE: 0.54 Item: Access Bed Covers To...
# 52: Guess: $14.97 Truth: $46.78 Error: $31.81 SLE: 1.20 Item: G.I. JOE Hasbro 3 3/...
# 53: Guess: $132.25 Truth: $171.44 Error: $39.19 SLE: 0.07 Item: T&S Brass Double Pan...
# 54: Guess: $241.00 Truth: $458.00 Error: $217.00 SLE: 0.41 Item: ZTUOAUMA Fuel Inject...
# 55: Guess: $162.25 Truth: $130.75 Error: $31.50 SLE: 0.05 Item: Hp Prime Graphing Ca...
# 56: Guess: $41.94 Truth: $83.81 Error: $41.87 SLE: 0.46 Item: Lowrance Nmea 2000 2...
# 57: Guess: $91.62 Truth: $386.39 Error: $294.76 SLE: 2.05 Item: Jeep Genuine Accesso...
# 58: Guess: $91.06 Truth: $169.00 Error: $77.94 SLE: 0.38 Item: GODOX CB-06 Hard Car...
# 59: Guess: $11.79 Truth: $17.95 Error: $6.16 SLE: 0.15 Item: Au-Tomotive Gold, IN...
# 60: Guess: $90.06 Truth: $269.00 Error: $178.94 SLE: 1.18 Item: Snailfly Black Roof ...
# 61: Guess: $34.44 Truth: $77.77 Error: $43.33 SLE: 0.64 Item: KING SHA Anti Glare ...
# 62: Guess: $89.06 Truth: $88.99 Error: $0.07 SLE: 0.00 Item: APS Compatible with ...
# 63: Guess: $131.50 Truth: $364.41 Error: $232.91 SLE: 1.03 Item: Wilwood Engineering ...
# 64: Guess: $85.31 Truth: $127.03 Error: $41.72 SLE: 0.16 Item: ACDelco Gold Starter...
# 65: Guess: $190.88 Truth: $778.95 Error: $588.08 SLE: 1.97 Item: UWS Matte Black Heav...
# 66: Guess: $265.00 Truth: $206.66 Error: $58.34 SLE: 0.06 Item: Dell Latitude E5440 ...
# 67: Guess: $23.81 Truth: $35.94 Error: $12.13 SLE: 0.16 Item: (Plug and Play) Spar...
# 68: Guess: $181.12 Truth: $149.00 Error: $32.12 SLE: 0.04 Item: The Ultimate Roadsid...
# 69: Guess: $190.50 Truth: $251.98 Error: $61.48 SLE: 0.08 Item: Brand New 18 x 8.5 R...
# 70: Guess: $49.31 Truth: $160.00 Error: $110.69 SLE: 1.35 Item: Headlight Headlamp L...
# 71: Guess: $30.91 Truth: $39.99 Error: $9.08 SLE: 0.06 Item: Lilo And Stitch Delu...
# 72: Guess: $120.88 Truth: $362.41 Error: $241.54 SLE: 1.19 Item: AC Compressor & A/C ...
# 73: Guess: $146.75 Truth: $344.00 Error: $197.25 SLE: 0.72 Item: House Of Troy Pinnac...
# 74: Guess: $37.25 Truth: $25.09 Error: $12.16 SLE: 0.15 Item: Juno T29 WH Floating...
# 75: Guess: $102.88 Truth: $175.95 Error: $73.07 SLE: 0.28 Item: Sherman GO-PARTS - f...
# 76: Guess: $99.75 Truth: $132.64 Error: $32.89 SLE: 0.08 Item: Roland RPU-3 Electro...
# 77: Guess: $248.75 Truth: $422.99 Error: $174.24 SLE: 0.28 Item: Rockland VMI14 12,00...
# 78: Guess: $102.38 Truth: $146.48 Error: $44.10 SLE: 0.13 Item: Max Advanced Brakes ...
# 79: Guess: $109.88 Truth: $156.83 Error: $46.96 SLE: 0.12 Item: Quality-Built 11030 ...
# 80: Guess: $146.75 Truth: $251.99 Error: $105.24 SLE: 0.29 Item: Lucida LG-510 Studen...
# 81: Guess: $50.88 Truth: $940.33 Error: $889.46 SLE: 8.40 Item: Longacre Aluminum Tu...
# 82: Guess: $24.91 Truth: $52.99 Error: $28.08 SLE: 0.54 Item: Motion Pro Adjustabl...
# 83: Guess: $177.00 Truth: $219.95 Error: $42.95 SLE: 0.05 Item: Glyph Thunderbolt 3 ...
# 84: Guess: $177.88 Truth: $441.03 Error: $263.15 SLE: 0.82 Item: TOYO Open Country MT...
# 85: Guess: $137.62 Truth: $168.98 Error: $31.35 SLE: 0.04 Item: Razer Seiren X USB S...
# 86: Guess: $10.28 Truth: $2.49 Error: $7.79 SLE: 1.38 Item: Happy Birthday to Da...
# 87: Guess: $135.38 Truth: $98.62 Error: $36.75 SLE: 0.10 Item: Little Tikes My Real...
# 88: Guess: $134.00 Truth: $256.95 Error: $122.95 SLE: 0.42 Item: Studio M Peace and H...
# 89: Guess: $22.00 Truth: $30.99 Error: $8.99 SLE: 0.11 Item: MyVolts 12V Power Su...
# 90: Guess: $514.50 Truth: $569.84 Error: $55.34 SLE: 0.01 Item: Dell Latitude 7212 R...
# 91: Guess: $48.91 Truth: $177.99 Error: $129.08 SLE: 1.63 Item: Covermates Contour F...
# 92: Guess: $147.12 Truth: $997.99 Error: $850.87 SLE: 3.64 Item: Westin Black HDX Gri...
# 93: Guess: $183.25 Truth: $219.00 Error: $35.75 SLE: 0.03 Item: Fieldpiece JL2 Job L...
# 94: Guess: $190.12 Truth: $225.55 Error: $35.43 SLE: 0.03 Item: hansgrohe Talis S Mo...
# 95: Guess: $509.50 Truth: $495.95 Error: $13.55 SLE: 0.00 Item: G-Technology G-SPEED...
# 96: Guess: $401.75 Truth: $942.37 Error: $540.62 SLE: 0.72 Item: DreamLine Shower Doo...
# 97: Guess: $12.20 Truth: $1.94 Error: $10.26 SLE: 2.26 Item: Sanctuary Square Bac...
# 98: Guess: $117.19 Truth: $284.34 Error: $167.15 SLE: 0.78 Item: Pelican Protector 17...
# 99: Guess: $116.75 Truth: $171.90 Error: $55.15 SLE: 0.15 Item: Brock Replacement Dr...
# 100: Guess: $101.69 Truth: $144.99 Error: $43.30 SLE: 0.12 Item: Carlinkit Ai Box Min...
# 101: Guess: $294.00 Truth: $470.47 Error: $176.47 SLE: 0.22 Item: StarDot YouTube Live...
# 102: Guess: $33.91 Truth: $66.95 Error: $33.04 SLE: 0.44 Item: Atomic Compatible ME...
# 103: Guess: $23.31 Truth: $117.00 Error: $93.69 SLE: 2.50 Item: Bandai Awakening of ...
# 104: Guess: $102.88 Truth: $172.14 Error: $69.26 SLE: 0.26 Item: Fit System 62135G Pa...
# 105: Guess: $182.38 Truth: $392.74 Error: $210.37 SLE: 0.58 Item: Black Horse Black Al...
# 106: Guess: $16.95 Truth: $16.99 Error: $0.04 SLE: 0.00 Item: Dearsun Twinkle Star...
# 107: Guess: $11.81 Truth: $1.34 Error: $10.47 SLE: 2.89 Item: Pokemon - Gallade Sp...
# 108: Guess: $180.00 Truth: $349.98 Error: $169.98 SLE: 0.44 Item: Ibanez GIO Series Cl...
# 109: Guess: $189.12 Truth: $370.71 Error: $181.58 SLE: 0.45 Item: Set 2 Heavy Duty 12 ...
# 110: Guess: $49.38 Truth: $65.88 Error: $16.50 SLE: 0.08 Item: Hairpin Table Legs 2...
# 111: Guess: $89.88 Truth: $229.99 Error: $140.12 SLE: 0.87 Item: Marada Racing Seat w...
# 112: Guess: $10.02 Truth: $9.14 Error: $0.88 SLE: 0.01 Item: Remington Industries...
# 113: Guess: $547.00 Truth: $199.00 Error: $348.00 SLE: 1.02 Item: Acer Ultrabook, Inte...
# 114: Guess: $102.75 Truth: $109.99 Error: $7.24 SLE: 0.00 Item: ICBEAMER 7 RGB LED H...
# 115: Guess: $101.56 Truth: $570.42 Error: $468.86 SLE: 2.95 Item: R1 Concepts Front Re...
# 116: Guess: $109.50 Truth: $279.99 Error: $170.49 SLE: 0.87 Item: Camplux 2.64 GPM Tan...
# 117: Guess: $20.31 Truth: $30.99 Error: $10.68 SLE: 0.16 Item: KNOKLOCK 10 Pack 3.7...
# 118: Guess: $24.91 Truth: $31.99 Error: $7.08 SLE: 0.06 Item: Valley Enterprises Y...
# 119: Guess: $23.42 Truth: $15.90 Error: $7.52 SLE: 0.14 Item: G9 LED Light 100W re...
# 120: Guess: $79.69 Truth: $45.99 Error: $33.70 SLE: 0.29 Item: ZCHAOZ 4 Lights Anti...
# 121: Guess: $96.44 Truth: $113.52 Error: $17.08 SLE: 0.03 Item: Honeywell Honeywell ...
# 122: Guess: $190.25 Truth: $516.99 Error: $326.74 SLE: 0.99 Item: Patriot Exhaust 1-7/...
# 123: Guess: $69.50 Truth: $196.99 Error: $127.49 SLE: 1.07 Item: Fitrite Autopart New...
# 124: Guess: $11.65 Truth: $46.55 Error: $34.90 SLE: 1.75 Item: Technical Precision ...
# 125: Guess: $80.25 Truth: $356.99 Error: $276.74 SLE: 2.20 Item: Covercraft Carhartt ...
# 126: Guess: $271.50 Truth: $319.95 Error: $48.45 SLE: 0.03 Item: Sennheiser SD Pro 2 ...
# 127: Guess: $45.31 Truth: $96.06 Error: $50.75 SLE: 0.55 Item: Hitachi Mass Air Flo...
# 128: Guess: $225.12 Truth: $190.99 Error: $34.13 SLE: 0.03 Item: AmScope LED Cordless...
# 129: Guess: $69.50 Truth: $257.95 Error: $188.45 SLE: 1.69 Item: Front Left Driver Si...
# 130: Guess: $34.44 Truth: $62.95 Error: $28.51 SLE: 0.35 Item: Premium Replica Hubc...
# 131: Guess: $31.14 Truth: $47.66 Error: $16.52 SLE: 0.17 Item: Excellerations Phoni...
# 132: Guess: $91.56 Truth: $226.99 Error: $135.43 SLE: 0.81 Item: RC4WD BigDog Dual Ax...
# 133: Guess: $133.00 Truth: $359.95 Error: $226.95 SLE: 0.98 Item: Unknown Stage 2 Clut...
# 134: Guess: $38.78 Truth: $78.40 Error: $39.62 SLE: 0.48 Item: Dodge Ram 1500 Mopar...
# 135: Guess: $161.88 Truth: $172.77 Error: $10.90 SLE: 0.00 Item: Pro Comp Alloys Seri...
# 136: Guess: $180.62 Truth: $316.45 Error: $135.82 SLE: 0.31 Item: Detroit Axle - Front...
# 137: Guess: $54.66 Truth: $87.99 Error: $33.33 SLE: 0.22 Item: ECCPP Rear Wheel Axl...
# 138: Guess: $301.00 Truth: $226.63 Error: $74.37 SLE: 0.08 Item: Dell Latitude E6520 ...
# 139: Guess: $22.17 Truth: $31.49 Error: $9.32 SLE: 0.11 Item: F FIERCE CYCLE 251pc...
# 140: Guess: $111.56 Truth: $196.00 Error: $84.44 SLE: 0.31 Item: Flash Furniture 4 Pk...
# 141: Guess: $20.30 Truth: $78.40 Error: $58.10 SLE: 1.73 Item: B&M 30287 Throttle V...
# 142: Guess: $70.00 Truth: $116.25 Error: $46.25 SLE: 0.25 Item: Gates TCK226 PowerGr...
# 143: Guess: $58.50 Truth: $112.78 Error: $54.28 SLE: 0.42 Item: Monroe Shocks & Stru...
# 144: Guess: $31.12 Truth: $27.32 Error: $3.80 SLE: 0.02 Item: Feit Electric 35W EQ...
# 145: Guess: $37.25 Truth: $145.91 Error: $108.66 SLE: 1.81 Item: Yellow Jacket 2806 C...
# 146: Guess: $48.56 Truth: $171.09 Error: $122.53 SLE: 1.55 Item: Garage-Pro Tailgate ...
# 147: Guess: $54.78 Truth: $167.95 Error: $113.17 SLE: 1.23 Item: 3M Perfect It Buffin...
# 148: Guess: $37.44 Truth: $28.49 Error: $8.95 SLE: 0.07 Item: Chinese Style Dollho...
# 149: Guess: $25.58 Truth: $122.23 Error: $96.65 SLE: 2.35 Item: Generic NRG Innovati...
# 150: Guess: $50.81 Truth: $32.99 Error: $17.82 SLE: 0.18 Item: Learning Resources C...
# 151: Guess: $31.17 Truth: $71.20 Error: $40.03 SLE: 0.65 Item: Bosch Automotive 154...
# 152: Guess: $37.69 Truth: $112.75 Error: $75.06 SLE: 1.16 Item: Case of 24-2 Inch Bl...
# 153: Guess: $64.69 Truth: $142.43 Error: $77.74 SLE: 0.61 Item: MOCA Engine Water Pu...
# 154: Guess: $147.00 Truth: $398.99 Error: $251.99 SLE: 0.99 Item: SAREMAS Foot Step Ba...
# 155: Guess: $449.75 Truth: $449.00 Error: $0.75 SLE: 0.00 Item: Gretsch G9210 Square...
# 156: Guess: $178.50 Truth: $189.00 Error: $10.50 SLE: 0.00 Item: NikoMaku Mirror Dash...
# 157: Guess: $109.56 Truth: $120.91 Error: $11.35 SLE: 0.01 Item: Fenix HP25R v2.0 USB...
# 158: Guess: $109.44 Truth: $203.53 Error: $94.09 SLE: 0.38 Item: R&L Racing Heavy Dut...
# 159: Guess: $276.50 Truth: $349.99 Error: $73.49 SLE: 0.06 Item: Garmin GPSMAP 64sx, ...
# 160: Guess: $10.93 Truth: $34.35 Error: $23.42 SLE: 1.18 Item: Brown 5-7/8 X 8-1/2 ...
# 161: Guess: $225.25 Truth: $384.99 Error: $159.74 SLE: 0.29 Item: GAOMON PD2200 Pen Di...
# 162: Guess: $145.88 Truth: $211.00 Error: $65.12 SLE: 0.13 Item: VXMOTOR for 97-03 Fo...
# 163: Guess: $300.00 Truth: $129.00 Error: $171.00 SLE: 0.70 Item: HP EliteBook 2540p I...
# 164: Guess: $20.14 Truth: $111.45 Error: $91.31 SLE: 2.79 Item: Green EPX Mixing Noz...
# 165: Guess: $18.72 Truth: $81.12 Error: $62.40 SLE: 2.04 Item: Box Partners 6 1/4 x...
# 166: Guess: $178.75 Truth: $457.08 Error: $278.33 SLE: 0.88 Item: Vixen Air 1/2 NPT Ai...
# 167: Guess: $102.00 Truth: $49.49 Error: $52.51 SLE: 0.51 Item: Smart Floor Lamp, Mu...
# 168: Guess: $31.16 Truth: $80.56 Error: $49.40 SLE: 0.87 Item: SOZG 324mm Wheelbase...
# 169: Guess: $168.25 Truth: $278.39 Error: $110.14 SLE: 0.25 Item: Mickey Thompson ET S...
# 170: Guess: $230.00 Truth: $364.50 Error: $134.50 SLE: 0.21 Item: Pirelli 106W XL RFT ...
# 171: Guess: $88.94 Truth: $378.99 Error: $290.05 SLE: 2.08 Item: Torklift C3212 Rear ...
# 172: Guess: $189.88 Truth: $165.28 Error: $24.59 SLE: 0.02 Item: Cardone Remanufactur...
# 173: Guess: $69.56 Truth: $56.74 Error: $12.82 SLE: 0.04 Item: Kidde AccessPoint 00...
# 174: Guess: $85.12 Truth: $307.95 Error: $222.82 SLE: 1.63 Item: 3M Protecta Self Ret...
# 175: Guess: $50.25 Truth: $38.00 Error: $12.25 SLE: 0.07 Item: Plantronics Wired He...
# 176: Guess: $71.12 Truth: $53.00 Error: $18.12 SLE: 0.08 Item: Logitech K750 Wirele...
# 177: Guess: $563.00 Truth: $498.00 Error: $65.00 SLE: 0.01 Item: Olympus PEN E-PL9 Bo...
# 178: Guess: $70.19 Truth: $53.99 Error: $16.20 SLE: 0.07 Item: Beck/Arnley Hub & Be...
# 179: Guess: $225.25 Truth: $350.00 Error: $124.75 SLE: 0.19 Item: Eibach Pro-Kit Perfo...
# 180: Guess: $193.00 Truth: $299.95 Error: $106.95 SLE: 0.19 Item: LEGO DC Batman 1989 ...
# 181: Guess: $146.50 Truth: $94.93 Error: $51.57 SLE: 0.19 Item: Kingston Brass Resto...
# 182: Guess: $246.25 Truth: $379.00 Error: $132.75 SLE: 0.18 Item: Polk Vanishing Serie...
# 183: Guess: $166.00 Truth: $299.95 Error: $133.95 SLE: 0.35 Item: Spec-D Tuning LED Pr...
# 184: Guess: $19.33 Truth: $24.99 Error: $5.66 SLE: 0.06 Item: RICHMOND & FINCH Air...
# 185: Guess: $99.06 Truth: $41.04 Error: $58.02 SLE: 0.75 Item: LFA Industries - mm ...
# 186: Guess: $58.69 Truth: $327.90 Error: $269.21 SLE: 2.91 Item: SAUTVS LED Headlight...
# 187: Guess: $19.25 Truth: $10.99 Error: $8.26 SLE: 0.27 Item: 2 Pack Combo Womens ...
# 188: Guess: $17.03 Truth: $14.99 Error: $2.04 SLE: 0.01 Item: Arepa - Venezuelan c...
# 189: Guess: $22.31 Truth: $84.95 Error: $62.64 SLE: 1.70 Item: Schlage Lock Company...
# 190: Guess: $103.19 Truth: $111.00 Error: $7.81 SLE: 0.01 Item: Techni Mobili White ...
# 191: Guess: $117.38 Truth: $123.73 Error: $6.36 SLE: 0.00 Item: Special Lite Product...
# 192: Guess: $59.88 Truth: $557.38 Error: $497.50 SLE: 4.91 Item: Tascam Digital Porta...
# 193: Guess: $117.19 Truth: $95.55 Error: $21.64 SLE: 0.04 Item: Glow Lighting Vista ...
# 194: Guess: $48.03 Truth: $154.00 Error: $105.97 SLE: 1.32 Item: Z3 Wind Deflector, S...
# 195: Guess: $436.50 Truth: $198.99 Error: $237.51 SLE: 0.61 Item: Olympus E-20 5MP Dig...
# 196: Guess: $134.12 Truth: $430.44 Error: $296.31 SLE: 1.35 Item: PHYNEDI 1 1000 World...
# 197: Guess: $23.89 Truth: $45.67 Error: $21.78 SLE: 0.40 Item: YANGHUAN Unstable Un...
# 198: Guess: $248.75 Truth: $249.00 Error: $0.25 SLE: 0.00 Item: Interlogix NetworX T...
# 199: Guess: $18.53 Truth: $42.99 Error: $24.46 SLE: 0.66 Item: Steering Damper,Univ...
# 200: Guess: $58.69 Truth: $181.33 Error: $122.64 SLE: 1.25 Item: Amprobe TIC 410A Hot...
# 201: Guess: $9.26 Truth: $6.03 Error: $3.23 SLE: 0.14 Item: MyCableMart 3.5mm Pl...
# 202: Guess: $38.88 Truth: $29.99 Error: $8.89 SLE: 0.06 Item: OtterBox + Pop Symme...
# 203: Guess: $650.00 Truth: $899.00 Error: $249.00 SLE: 0.10 Item: Dell XPS Desktop ( I...
# 204: Guess: $335.25 Truth: $399.99 Error: $64.74 SLE: 0.03 Item: Franklin Iron Works ...
# 205: Guess: $23.83 Truth: $4.66 Error: $19.17 SLE: 2.19 Item: Avery Legal Dividers...
# 206: Guess: $168.00 Truth: $261.41 Error: $93.41 SLE: 0.19 Item: Moen 8346 Commercial...
# 207: Guess: $128.12 Truth: $136.97 Error: $8.84 SLE: 0.00 Item: Carlisle Versa Trail...
# 208: Guess: $54.75 Truth: $79.00 Error: $24.25 SLE: 0.13 Item: SUNWAYFOTO 44mm Trip...
# 209: Guess: $210.88 Truth: $444.99 Error: $234.12 SLE: 0.55 Item: NanoBeam AC 4 Units ...
# 210: Guess: $222.75 Truth: $411.94 Error: $189.19 SLE: 0.38 Item: WULF 4 Front 2 Rear ...
# 211: Guess: $190.50 Truth: $148.40 Error: $42.10 SLE: 0.06 Item: Alera ALEVABFMC Vale...
# 212: Guess: $36.22 Truth: $244.99 Error: $208.77 SLE: 3.57 Item: YU-GI-OH! Ignition A...
# 213: Guess: $80.62 Truth: $86.50 Error: $5.88 SLE: 0.00 Item: 48 x 36 Extra-Large ...
# 214: Guess: $224.62 Truth: $297.95 Error: $73.32 SLE: 0.08 Item: Dell Latitude D620 R...
# 215: Guess: $398.50 Truth: $399.99 Error: $1.49 SLE: 0.00 Item: acer Aspire 5 Laptop...
# 216: Guess: $163.25 Truth: $599.00 Error: $435.75 SLE: 1.68 Item: Elk 30 by 6-Inch Viv...
# 217: Guess: $24.94 Truth: $105.99 Error: $81.05 SLE: 2.01 Item: Barbie Top Model Dol...
# 218: Guess: $450.50 Truth: $689.00 Error: $238.50 SLE: 0.18 Item: Danby Designer 20-In...
# 219: Guess: $216.50 Truth: $404.99 Error: $188.49 SLE: 0.39 Item: FixtureDisplays® Met...
# 220: Guess: $106.38 Truth: $207.76 Error: $101.38 SLE: 0.44 Item: ACDelco GM Original ...
# 221: Guess: $190.50 Truth: $171.82 Error: $18.68 SLE: 0.01 Item: EBC Premium Street B...
# 222: Guess: $224.50 Truth: $293.24 Error: $68.74 SLE: 0.07 Item: FXR Men's Boost FX J...
# 223: Guess: $109.00 Truth: $374.95 Error: $265.95 SLE: 1.51 Item: SuperATV Scratch Res...
# 224: Guess: $34.34 Truth: $111.99 Error: $77.65 SLE: 1.35 Item: SBU 3 Layer All Weat...
# 225: Guess: $16.05 Truth: $42.99 Error: $26.94 SLE: 0.90 Item: 2 Pack Outdoor Broch...
# 226: Guess: $65.12 Truth: $116.71 Error: $51.58 SLE: 0.33 Item: Monroe Shocks & Stru...
# 227: Guess: $227.50 Truth: $118.61 Error: $108.89 SLE: 0.42 Item: Elements of Design M...
# 228: Guess: $106.00 Truth: $147.12 Error: $41.12 SLE: 0.11 Item: GM Genuine Parts Air...
# 229: Guess: $162.38 Truth: $119.99 Error: $42.39 SLE: 0.09 Item: Baseus USB C Docking...
# 230: Guess: $190.38 Truth: $369.98 Error: $179.61 SLE: 0.44 Item: Whitehall™ Personali...
# 231: Guess: $102.62 Truth: $315.55 Error: $212.93 SLE: 1.25 Item: Pro Circuit Works Pi...
# 232: Guess: $276.50 Truth: $190.99 Error: $85.51 SLE: 0.14 Item: HYANKA 15 1200W Prof...
# 233: Guess: $60.19 Truth: $155.00 Error: $94.81 SLE: 0.88 Item: Bluetooth X6BT Card ...
# 234: Guess: $90.50 Truth: $349.99 Error: $259.49 SLE: 1.81 Item: AIRAID Cold Air Inta...
# 235: Guess: $132.75 Truth: $249.99 Error: $117.24 SLE: 0.40 Item: Bostingner Shower Fa...
# 236: Guess: $34.81 Truth: $42.99 Error: $8.18 SLE: 0.04 Item: PIT66 Front Bumper T...
# 237: Guess: $12.68 Truth: $17.99 Error: $5.31 SLE: 0.11 Item: Caseology Bumpy Comp...
# 238: Guess: $109.50 Truth: $425.00 Error: $315.50 SLE: 1.82 Item: Fleck 2510 Timer Mec...
# 239: Guess: $164.12 Truth: $249.99 Error: $85.87 SLE: 0.18 Item: Haloview MC7108 Wire...
# 240: Guess: $27.11 Truth: $138.23 Error: $111.12 SLE: 2.56 Item: Schmidt Spiele - Man...
# 241: Guess: $192.50 Truth: $414.99 Error: $222.49 SLE: 0.59 Item: Corsa 14333 Tip Kit ...
# 242: Guess: $172.12 Truth: $168.28 Error: $3.84 SLE: 0.00 Item: Hoshizaki FM116A Fan...
# 243: Guess: $116.62 Truth: $199.99 Error: $83.37 SLE: 0.29 Item: BAINUO Antler Chande...
# 244: Guess: $51.78 Truth: $126.70 Error: $74.92 SLE: 0.78 Item: DNA MOTORING Smoke L...
# 245: Guess: $10.95 Truth: $5.91 Error: $5.04 SLE: 0.30 Item: Wera Stainless 3840/...
# 246: Guess: $191.25 Truth: $193.06 Error: $1.81 SLE: 0.00 Item: Celestron - PowerSee...
# 247: Guess: $226.88 Truth: $249.99 Error: $23.12 SLE: 0.01 Item: NHOPEEW Android Car ...
# 248: Guess: $37.50 Truth: $64.12 Error: $26.62 SLE: 0.28 Item: Other Harmonica A)
# F...
# 249: Guess: $69.00 Truth: $114.99 Error: $45.99 SLE: 0.26 Item: Harley Air Filter Ve...
# 250: Guess: $253.12 Truth: $926.00 Error: $672.88 SLE: 1.67 Item: Elite Screens Edge F...
